# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarteel89/Prediction-of-Product-Sales/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediction of Product Sales.

# %% [markdown]
# - Author : Tarteel Abu Ghazaleh

# %% [markdown]
# ## Project Overview

# %% [markdown]
# ## Load and Inspect Data

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ## Explratory Data Analysis

# %% [markdown]
# ## Feature Inspection
